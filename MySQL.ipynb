# %%
from sqlalchemy import create_engine
import pymysql
import pandas as pd

# %%
engine = create_engine("mysql+pymysql://root:root@localhost/toko")

# %%
data = pd.read_sql('select * from barangs', con=engine)

# %%
data.head()
# Out:
#    id  category_id                   name                      merek  stok  \
# 0   1            2            Paracetamol                  Hufagesic     9
# 1   2            2     Amoxicillin 500 mg                  Penisilin    10
# 2   3            3           Suntik Medis  Disposable Syringe (10ml)   197
# 3   4            4                Pempres             MamyPoko Pants   150
# 4   5            6  Acetylcysteine 200 mg                    Etercon   150
#
#    minimal_stok jumlahrencana kadaluwarsa  harga              gambar  \
# 0            15          None  2026-06-17  10000     paracetamol.jpg
# 1            15          None  2026-10-01   8000     amoxicillin.jpg
# 2            15          None  2023-10-01   3000          suntik.jpg
# 3            15          None  2025-10-01  45000         pempres.jpg
# 4            15          None  2025-10-02  45000  acetylcysteine.jpg
#
#                                            deskripsi  \
# ...
